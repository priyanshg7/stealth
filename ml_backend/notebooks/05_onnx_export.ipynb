# %% [markdown]
# # ONNX Export Wrapper
# Export PyTorch weights to ONNX format for deployment.

# %%
import sys
sys.path.append('../src/')
from export_onnx import export_to_onnx

config_file = '../configs/tomato.yaml'
checkpoint_path = '../models/checkpoints/tomato/best_model.pth'
output_onnx = '../models/tomato_classifier.onnx'

# Uncomment to run export:
# export_to_onnx(config_file, checkpoint_path, output_onnx)
