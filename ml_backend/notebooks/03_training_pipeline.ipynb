# %% [markdown]
# # Training Pipeline Wrapper
# This notebook allows you to start the PyTorch training loop interactively.

# %%
import sys
sys.path.append('../src/')
from train import train

# Select which crop config to train on
config_file = '../configs/tomato.yaml'

# Note: Running this cell will initialize wandb and start the training loop.
# Uncomment to run:
# train(config_file)
