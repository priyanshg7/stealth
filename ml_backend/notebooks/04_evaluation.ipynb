# %% [markdown]
# # Evaluation Wrapper
# Evaluate the model against the holdout test set and generate a confusion matrix.

# %%
import sys
sys.path.append('../src/')
from evaluate import evaluate

config_file = '../configs/tomato.yaml'
checkpoint_path = '../models/checkpoints/tomato/best_model.pth'

# Uncomment to run evaluation (requires a trained model):
# evaluate(config_file, checkpoint_path)
